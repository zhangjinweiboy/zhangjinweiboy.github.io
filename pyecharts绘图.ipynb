# %% [markdown]
# ### 导入相关环境

# %%
# 导入包
import pandas as pd
import os 
import pyecharts
from pyecharts.charts import *
from pyecharts import options as opts 
from pyecharts.globals import ThemeType

# %%
# 导入数据
os.getcwd()
os.chdir("/Users/zhangjinwei/Desktop/机器学习/001_学习数据/")
data_rk = pd.read_csv("出生人口数据.csv")
data_csl =pd.read_csv("001_出生率.csv")

# %% [markdown]
# ### 绘制散点图

# %% [markdown]
# #### 绘制单点散点图

# %%
# 单绘制单散点图
import pyecharts.options as opts
from pyecharts.charts import Scatter

x_data = data_rk.iloc[0:31,:]["id"]
y_data1 = data_rk.iloc[0:31,:]["E"]
y_data2 = data_rk.iloc[0:31,:]["renkou"]

(
    Scatter(init_opts=opts.InitOpts(width="800px", height="460px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="序列1",
        y_axis=y_data1,
        symbol_size=10,
        label_opts=opts.LabelOpts(is_show=False),
    )  
    .set_series_opts()
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(name = "x轴标签", type_="value", splitline_opts=opts.SplitLineOpts(is_show=True) ),
        yaxis_opts=opts.AxisOpts(name = "y轴标签", type_="value", splitline_opts=opts.SplitLineOpts(is_show=True), axistick_opts=opts.AxisTickOpts(is_show=True) ),
        title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        legend_opts=opts.LegendOpts(is_show = True),
        datazoom_opts=opts.DataZoomOpts(is_show = True)
    )
   .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d05995070679457cace45cfb42cd37c3" style="width:800px; height:460px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d05995070679457cace45cfb42cd37c3 = echarts.init(
#                     document.getElementById('d05995070679457cace45cfb42cd37c3'), 'white', {renderer: 'canvas'});
#                 var option_d05995070679457cace45cfb42cd37c3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# #### 绘制多组散点图

# %%
# 绘制多组散点图
import pyecharts.options as opts
from pyecharts.charts import Scatter

x_data = data_rk.iloc[0:31,:]["id"]
y_data1 = data_rk.iloc[0:31,:]["E"]
y_data2 = data_rk.iloc[0:31,:]["renkou"]

(
    Scatter(init_opts=opts.InitOpts(width="800px", height="460px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="序列1",
        y_axis=y_data1,
        symbol_size=10,
        label_opts=opts.LabelOpts(is_show=False),
    )
     .add_yaxis(
        series_name="序列2",
        y_axis=y_data2,
        symbol_size=10,
        label_opts=opts.LabelOpts(is_show=False),
    )  
    .set_series_opts()
    .set_global_opts(
        xaxis_opts=opts.AxisOpts(name = "x轴标签", type_="value", splitline_opts=opts.SplitLineOpts(is_show=True) ),
        yaxis_opts=opts.AxisOpts(name = "y轴标签", type_="value", splitline_opts=opts.SplitLineOpts(is_show=True), axistick_opts=opts.AxisTickOpts(is_show=True) ),
        title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        legend_opts=opts.LegendOpts(is_show = True),
        datazoom_opts=opts.DataZoomOpts(is_show = True)
    )
   .render_notebook()
)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="db865777e68a415a8d9308988fcfabc5" style="width:800px; height:460px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_db865777e68a415a8d9308988fcfabc5 = echarts.init(
#                     document.getElementById('db865777e68a415a8d9308988fcfabc5'), 'white', {renderer: 'canvas'});
#                 var option_db865777e68a415a8d9308988fcfabc5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ###  绘制柱状图

# %% [markdown]
# ####  绘制单组柱状图

# %%
# 绘制单组柱状图

df = data_csl
x = list(df["地区"])
y1 = list(df["2011"])

bar = (
    Bar(init_opts=opts.InitOpts (theme= ThemeType.WHITE,           
                                 bg_color="white",                 
                                 width="1000px", height="500px"    
                                 ) ) 
    # 可通过 theme= ThemeType.WHITE 更换主题
    # 修改背景颜色，若删除则变为黑色，不便于观看。
    # 可通过此处调整图片大小，也可以删除此处。
    .add_xaxis(x) 
    .add_yaxis("y标签", y1, gap="2%", 
               markpoint_opts=opts.MarkPointOpts(data = [opts.MarkPointItem(type_ = "max")]),
               markline_opts=opts.MarkLineOpts(data =[opts.MarkLineItem( y = 12 ) ] ))  
     # "2011"在图例中显示，不可删除。 通过 gap="2%" 设置不同柱之间的间距，不需要可以删除。
     # markpoint_opts, markline_opts, 可以添加标记点和标记线。 
     # .add_yaxis() 可以继续添加多类柱状图，展示为分组柱状图。
     
    ## 添加全局设置
    .set_global_opts( xaxis_opts = opts.AxisOpts(name = "x轴标签", axislabel_opts=opts.LabelOpts(rotate=65)),
                      yaxis_opts = opts.AxisOpts(name = "y轴标签"),
                      title_opts = opts.TitleOpts( title ="主标题", subtitle="副标题" ),          
                      legend_opts  = opts.LegendOpts(is_show=False),   
                      toolbox_opts = opts.ToolboxOpts(),  
                      datazoom_opts= opts.DataZoomOpts(is_show=True, type_="slider"), 
                      tooltip_opts = opts.TooltipOpts(trigger="axis", axis_pointer_type="cross") 
                      )  
      # axislabel_opts 调整X轴标签的角度，可表示为-35
      # legend_opts   显示图例
      # toolbox_opts  展示工具箱
      # datazoom_opts 显示缩放条,type_="inside"会隐藏缩放条，但是可以缩放。需要显示缩放条，删除type_="inside"即可。
      # tooltip_opts  添加坐标线，选中某个点时，会出现坐标虚线，不需要可以删除。
      # .reversal_axis()  # 翻转柱状图
      
    ## 对所有序列设置-标记点，标记线。
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
                ]
            ) ,
        markline_opts=opts.MarkLineOpts(data = [opts.MarkLineItem(type_="average",name = "平均值")] )
    )
    # opts.LabelOpts(is_show=False) 设置在各列上不显示数值
    # .set_series_opts 优先级大于在 .add_yaxis()中的设置。若已经在.add_yaxis()中设置，此处可以删除。
)
bar.render_notebook()
# 在notebook中显示
# 输出为一个html的文件
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fadde784d7ac4413a524fa218407483b" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fadde784d7ac4413a524fa218407483b = echarts.init(
#                     document.getElementById('fadde784d7ac4413a524fa218407483b'), 'white', {renderer: 'canvas'});
#                 var option_fadde784d7ac4413a524fa218407483b = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %% [markdown]
# #### 绘制分组柱状图

# %%
# 绘制分组柱状图

df = data_csl
x = list(df["地区"])
y1 = list(df["2011"])
y2 = list(df["2015"])
y3 = list(df["2019"])

bar = (
    Bar(init_opts=opts.InitOpts (theme= ThemeType.WHITE,           
                                 bg_color="white",                 
                                 width="1000px", height="500px"    
                                 ) ) 
    # 可通过 theme= ThemeType.WHITE 更换主题
    # 修改背景颜色，若删除则变为黑色，不便于观看。
    # 可通过此处调整图片大小，也可以删除此处。
    .add_xaxis(x) 
    .add_yaxis("y标签", y1, gap="2%", 
               markpoint_opts=opts.MarkPointOpts(data = [opts.MarkPointItem(type_ = "max")]),
               markline_opts=opts.MarkLineOpts(data =[opts.MarkLineItem( y = 12 ) ] ))  
    .add_yaxis("2015", y2, gap="2%", )  
    .add_yaxis("2019", y3, gap="2%",  ) 
     # "2011"在图例中显示，不可删除。 通过 gap="2%" 设置不同柱之间的间距，不需要可以删除。
     # markpoint_opts, markline_opts, 可以添加标记点和标记线。 
     # .add_yaxis() 可以继续添加多类柱状图，展示为分组柱状图。
     
    ## 添加全局设置
    .set_global_opts( xaxis_opts = opts.AxisOpts(name = "x轴标签", axislabel_opts=opts.LabelOpts(rotate=65)),
                      yaxis_opts = opts.AxisOpts(name = "y轴标签"),
                      title_opts = opts.TitleOpts( title ="主标题", subtitle="副标题" ),          
                      legend_opts  = opts.LegendOpts(is_show=False),   
                      toolbox_opts = opts.ToolboxOpts(),  
                      datazoom_opts= opts.DataZoomOpts(is_show=True, type_="slider"), 
                      tooltip_opts = opts.TooltipOpts(trigger="axis", axis_pointer_type="cross") 
                      )  
      # axislabel_opts 调整X轴标签的角度，可表示为-35
      # legend_opts   显示图例
      # toolbox_opts  展示工具箱
      # datazoom_opts 显示缩放条,type_="inside"会隐藏缩放条，但是可以缩放。需要显示缩放条，删除type_="inside"即可。
      # tooltip_opts  添加坐标线，选中某个点时，会出现坐标虚线，不需要可以删除。
      # .reversal_axis()  # 翻转柱状图
      
    ## 对所有序列设置-标记点，标记线。
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False)
    )
    # opts.LabelOpts(is_show=False) 设置在各列上不显示数值
    # .set_series_opts 优先级大于在 .add_yaxis()中的设置。若已经在.add_yaxis()中设置，此处可以删除。
)      
bar.render_notebook()
# 在notebook中显示
# 输出为一个html的文件
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="435ea480172948f2ae27ded0108dae66" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_435ea480172948f2ae27ded0108dae66 = echarts.init(
#                     document.getElementById('435ea480172948f2ae27ded0108dae66'), 'white', {renderer: 'canvas'});
#                 var option_435ea480172948f2ae27ded0108dae66 = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %% [markdown]
# ### 2. 绘制折线图

# %%
# 导入环境
import pandas as pd
import os 
import pyecharts
from pyecharts.charts import *
from pyecharts import options as opts 
from pyecharts.globals import ThemeType

# %% [markdown]
# Line图和Bar图的代码几乎完全一样，只有细微差别。

# %% [markdown]
# #### 绘制单组折线图

# %%
# 绘制单组折线图
from pyecharts.charts import Line
# 很奇怪，每次运行次，第二次调用Line就会失败
df = data_csl
x = list(df["地区"])
y1 = list(df["2011"])

Line = (
    Line(init_opts=opts.InitOpts (theme= ThemeType.WHITE,           
                                 bg_color="white",                 
                                 width="1000px", height="400px"    
                                 ) ) 
    # 可通过 theme= ThemeType.WHITE 更换主题
    # 修改背景颜色，若删除则变为黑色，不便于观看。
    # 可通过此处调整图片大小，也可以删除此处。
    .add_xaxis(x) 
    .add_yaxis("y标签", y1, 
               markpoint_opts=opts.MarkPointOpts(data = [opts.MarkPointItem(type_ = "max")]),
               markline_opts=opts.MarkLineOpts(data =[opts.MarkLineItem( y = 12 ) ] ))  
     # "2011"在图例中显示，不可删除。 通过 gap="2%" 设置不同柱之间的间距，不需要可以删除。
     # markpoint_opts, markline_opts, 可以添加标记点和标记线。 
     # .add_yaxis() 可以继续添加多类柱状图，展示为分组柱状图。
     
    ## 添加全局设置
    .set_global_opts( xaxis_opts = opts.AxisOpts(name = "x轴标签", axislabel_opts=opts.LabelOpts(rotate=65)),
                      yaxis_opts = opts.AxisOpts(name = "y轴标签"),
                      title_opts = opts.TitleOpts( title ="主标题", subtitle="副标题" ),          
                      legend_opts  = opts.LegendOpts(is_show=False),   
                      toolbox_opts = opts.ToolboxOpts(),  
                      datazoom_opts= opts.DataZoomOpts(is_show=True, type_="slider"), 
                      tooltip_opts = opts.TooltipOpts(trigger="axis", axis_pointer_type="cross") 
                      )  
      # axislabel_opts 调整X轴标签的角度，可表示为-35
      # legend_opts   显示图例
      # toolbox_opts  展示工具箱
      # datazoom_opts 显示缩放条,type_="inside"会隐藏缩放条，但是可以缩放。需要显示缩放条，删除type_="inside"即可。
      # tooltip_opts  添加坐标线，选中某个点时，会出现坐标虚线，不需要可以删除。
      # .reversal_axis()  # 翻转柱状图
      
    ## 对所有序列设置-标记点，标记线。优先级大于在 .add_yaxis()中的设置。若已经在.add_yaxis()中设置，此处可以删除。
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False),
        markpoint_opts=opts.MarkPointOpts(
            data=[
                opts.MarkPointItem(type_="max", name="最大值"),
                opts.MarkPointItem(type_="min", name="最小值"),
                ]
            ) ,
        markline_opts=opts.MarkLineOpts(data = [opts.MarkLineItem(type_="average",name = "平均值")] )
    )
)
Line.render_notebook()
# 在notebook中显示
# 输出为一个html的文件
# Line.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3806a2db5b53478abe0df3a35eb16b2f" style="width:1000px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3806a2db5b53478abe0df3a35eb16b2f = echarts.init(
#                     document.getElementById('3806a2db5b53478abe0df3a35eb16b2f'), 'white', {renderer: 'canvas'});
#                 var option_3806a2db5b53478abe0df3a35eb16b2f = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %% [markdown]
# #### 绘制分组柱状图

# %%
# 绘制分组柱状图
from pyecharts.charts import Line
# 很奇怪，每次运行次，第二次调用Line就会失败
df = data_csl
x = list(df["地区"])
y1 = list(df["2011"])
y2 = list(df["2015"])
y3 = list(df["2019"])

Line = (
    Line(init_opts=opts.InitOpts (theme= ThemeType.WHITE,           
                                 bg_color="white",                 
                                 width="1000px", height="400px"    
                                 ) ) 
    # 可通过 theme= ThemeType.WHITE 更换主题
    # 修改背景颜色，若删除则变为黑色，不便于观看。
    # 可通过此处调整图片大小，也可以删除此处。
    .add_xaxis(x) 
    .add_yaxis("y标签", y1,
               markpoint_opts=opts.MarkPointOpts(data = [opts.MarkPointItem(type_ = "max")]),
               markline_opts=opts.MarkLineOpts(data =[opts.MarkLineItem( y = 12 ) ] ))  
    .add_yaxis("2015", y2,  )  
    .add_yaxis("2019", y3, ) 
     # "2011"在图例中显示，不可删除。 通过 gap="2%" 设置不同柱之间的间距，不需要可以删除。
     # markpoint_opts, markline_opts, 可以添加标记点和标记线。 
     # .add_yaxis() 可以继续添加多类柱状图，展示为分组柱状图。
     
    ## 添加全局设置
    .set_global_opts( xaxis_opts = opts.AxisOpts(name = "x轴标签", axislabel_opts=opts.LabelOpts(rotate=65)),
                      yaxis_opts = opts.AxisOpts(name = "y轴标签"),
                      title_opts = opts.TitleOpts( title ="主标题", subtitle="副标题" ),          
                      legend_opts  = opts.LegendOpts(is_show=False),   
                      toolbox_opts = opts.ToolboxOpts(),  
                      datazoom_opts= opts.DataZoomOpts(is_show=True, type_="slider"), 
                      tooltip_opts = opts.TooltipOpts(trigger="axis", axis_pointer_type="cross") 
                      )  
      # axislabel_opts 调整X轴标签的角度，可表示为-35
      # legend_opts   显示图例
      # toolbox_opts  展示工具箱
      # datazoom_opts 显示缩放条,type_="inside"会隐藏缩放条，但是可以缩放。需要显示缩放条，删除type_="inside"即可。
      # tooltip_opts  添加坐标线，选中某个点时，会出现坐标虚线，不需要可以删除。
      # .reversal_axis()  # 翻转柱状图
      
    ## 对所有序列设置-标记点，标记线。
    .set_series_opts(
        label_opts=opts.LabelOpts(is_show=False)
    )
    # opts.LabelOpts(is_show=False) 设置在各列上不显示数值
    # .set_series_opts 优先级大于在 .add_yaxis()中的设置。若已经在.add_yaxis()中设置，此处可以删除。
)      
Line.render_notebook()
# 在notebook中显示
# 输出为一个html的文件
# bar.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a5dabc8427da4b8dbcdd0201af5355ee" style="width:1000px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a5dabc8427da4b8dbcdd0201af5355ee = echarts.init(
#                     document.getElementById('a5dabc8427da4b8dbcdd0201af5355ee'), 'white', {renderer: 'canvas'});
#                 var option_a5dabc8427da4b8dbcdd0201af5355ee = {
#     "backgroundColor": "white",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
# ...

# %% [markdown]
# ### 绘制饼状图

# %% [markdown]
# #### 绘制单饼状图

# %%
# 绘制饼状图

y5=['可乐', '雪碧', '橙汁', '绿茶', '奶茶', '百威', '青岛']
y6=[85, 92, 126, 80, 95, 144, 116]
pie = (
    Pie()
    .add("",
         [list(z) for z in zip(y5, y6)], 
         ) 
    # 此处替换y5,y6即可，不要动[list(z) for z in zip(y5, y6)]中的其他地方。
    .set_global_opts(title_opts = opts.TitleOpts(title = "Pie-月度开支"))
     # 设置格式，默认为下列设置
     # .set_series_opts(label_opts = opts.LabelOpts(formatter = "{b}: {c}"))
     # 可以指定颜色
     #.set_colors(["blue", "green", "purple", "red", "pink"]) 
)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5ad2ac5d947047ef97ef4233e1cc47da" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5ad2ac5d947047ef97ef4233e1cc47da = echarts.init(
#                     document.getElementById('5ad2ac5d947047ef97ef4233e1cc47da'), 'white', {renderer: 'canvas'});
#                 var option_5ad2ac5d947047ef97ef4233e1cc47da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ### 绘制玫瑰图

# %%
# 绘制玫瑰图

y5=['可乐', '雪碧', '橙汁', '绿茶', '奶茶', '百威', '青岛']
y6=[85, 92, 126, 80, 95, 144, 116]
pie = (
    Pie()
    .add("",
         [list(z) for z in zip(y5, y6)], 
         radius=["25%", "75%"],
         center=["50%", "50%"],
         rosetype="radius",
         label_opts=opts.LabelOpts(is_show=True),
         ) 
    # 此处替换y5,y6即可，不要动[list(z) for z in zip(y5, y6)]中的其他地方。
    .set_global_opts(title_opts = opts.TitleOpts(title = "Pie-月度开支"))
     # 设置格式，默认为下列设置
     # .set_series_opts(label_opts = opts.LabelOpts(formatter = "{b}: {c}"))
     # 可以指定颜色
     #.set_colors(["blue", "green", "purple", "red", "pink"]) 
)
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="17c1df0c739345ccb309ab38ae9f5342" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_17c1df0c739345ccb309ab38ae9f5342 = echarts.init(
#                     document.getElementById('17c1df0c739345ccb309ab38ae9f5342'), 'white', {renderer: 'canvas'});
#                 var option_17c1df0c739345ccb309ab38ae9f5342 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# #### 绘制多组饼状图

# %%
# 绘制多组饼状图

c = (
    Pie(init_opts=opts.InitOpts(width="1000px",height="500px"))
    .add(
        "",
        [list(z) for z in zip(y5, y6)],
        radius=["30%", "75%"],
        center=["25%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=True),
    )
    .add(
        "",
        [list(z) for z in zip(y5, y6)],
        radius=["30%", "75%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ac36134c9d4841b6b08641dbf012b0f7" style="width:1000px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ac36134c9d4841b6b08641dbf012b0f7 = echarts.init(
#                     document.getElementById('ac36134c9d4841b6b08641dbf012b0f7'), 'white', {renderer: 'canvas'});
#                 var option_ac36134c9d4841b6b08641dbf012b0f7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ### 3. 绘制组图，两个图上下分布

# %%
# 绘制组图，两个图上下分布

from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line
from pyecharts.faker import Faker

bar = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
)
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
        legend_opts=opts.LegendOpts(pos_top="48%"),
    )
)

grid = (
    Grid(init_opts=opts.InitOpts(width="680px", height="500px"))
    .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))
    .add(line, grid_opts=opts.GridOpts(pos_top="60%"))
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7ace202e0c5f445b96361517c28b7611" style="width:680px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7ace202e0c5f445b96361517c28b7611 = echarts.init(
#                     document.getElementById('7ace202e0c5f445b96361517c28b7611'), 'white', {renderer: 'canvas'});
#                 var option_7ace202e0c5f445b96361517c28b7611 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 绘制组图，两个图上下分布

df = data_csl
x = list(df["地区"])
y1 = list(df["2011"])
y2 = list(df["2015"])
y3 = list(df["2019"])

bar = (
    Bar(init_opts=opts.InitOpts (theme= ThemeType.WHITE,           
                                 bg_color="white",                 
                                 width="1000px", height="500px"    
                                 )) 
    .add_xaxis(x) 
    .add_yaxis("2011", y1, gap="2%") 
    .add_yaxis("2015", y2, gap="2%")  
    .add_yaxis("2019", y3, gap="2%")   
    .set_global_opts( xaxis_opts=opts.AxisOpts(name = "x轴标签", axislabel_opts=opts.LabelOpts(rotate=65)),
                      yaxis_opts=opts.AxisOpts(name = "y轴标签"),
                      title_opts=opts.TitleOpts( title ="主标题", subtitle="副标题" ),
                      toolbox_opts=opts.ToolboxOpts(is_show=True),
                      datazoom_opts= opts.DataZoomOpts(is_show = True),
                      tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"), 
                      )  
    .set_series_opts(label_opts=opts.LabelOpts(is_show = False))
)

line = (
    Line(init_opts=opts.InitOpts(theme=ThemeType.ROMA, bg_color="white",width='1000px',height='300px' ))
    .add_xaxis(x)
    .add_yaxis("2011", y1,)
    .add_yaxis("2015", y2, markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="min")]))
    .add_yaxis("2019",y3, markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_="max")]) )
    .set_global_opts(xaxis_opts=opts.AxisOpts(name = "x轴标签", axislabel_opts=opts.LabelOpts(rotate=65)), 
                      yaxis_opts=opts.AxisOpts(name = "y轴标签"),
                      title_opts=opts.TitleOpts(title="主标题", subtitle="副标题"),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
        legend_opts=opts.LegendOpts(is_show=True),  
                
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show = False))
)

grid = (
    Grid()
    .add(bar,grid_opts=opts.GridOpts(pos_bottom="60%"))
    .add(line,grid_opts=opts.GridOpts(pos_top="60%"))         
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6f9bae71daf848b3a5ec0c5d0a07dc81" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6f9bae71daf848b3a5ec0c5d0a07dc81 = echarts.init(
#                     document.getElementById('6f9bae71daf848b3a5ec0c5d0a07dc81'), 'white', {renderer: 'canvas'});
#                 var option_6f9bae71daf848b3a5ec0c5d0a07dc81 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ### 4. 绘制堆叠图

# %%
# 绘制堆叠图
from pyecharts import options as opts
from pyecharts.charts import Bar, Line
from pyecharts.faker import Faker

v1 = [2.0, 4.9, 7.0, 23.2, 25.6, 76.7, 135.6, 162.2, 32.6, 20.0, 6.4, 3.3]
v2 = [2.6, 5.9, 9.0, 26.4, 28.7, 70.7, 175.6, 182.2, 48.7, 18.8, 6.0, 2.3]
v3 = [2.0, 2.2, 3.3, 4.5, 6.3, 10.2, 20.3, 23.4, 23.0, 16.5, 12.0, 6.2]


bar = (
    Bar(init_opts=opts.InitOpts(width="680px", height="300px"))
    .add_xaxis(Faker.months)
    .add_yaxis("蒸发量", v1)
    .add_yaxis("降水量", v2)
    .extend_axis(
        yaxis=opts.AxisOpts(
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"), interval=5
        )
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Overlap-bar+line"),
        yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value} ml")),
        tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
    )
)

line = (
    Line()
    .add_xaxis(Faker.months)
    .add_yaxis("平均温度", v3, yaxis_index=1)  
)

bar.overlap(line)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="09bdce292e414923a7dc5023d06d03cd" style="width:680px; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_09bdce292e414923a7dc5023d06d03cd = echarts.init(
#                     document.getElementById('09bdce292e414923a7dc5023d06d03cd'), 'white', {renderer: 'canvas'});
#                 var option_09bdce292e414923a7dc5023d06d03cd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ### 绘制带有时间序列的图

# %% [markdown]
# #### 绘制带有时间序列的饼状图

# %%
# 绘制时间序列饼图
from pyecharts import options as opts
from pyecharts.charts import Pie, Timeline
from pyecharts.faker import Faker

attr = Faker.choose()
tl = Timeline()
for i in range(2015, 2020):
    pie = (
        Pie()
        .add(
            "商家A",
            [list(z) for z in zip(attr, Faker.values())],
            rosetype="radius",
            radius=["30%", "55%"],
        )
        .set_global_opts(title_opts=opts.TitleOpts("某商店{}年营业额".format(i)))
    )
    tl.add(pie, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8296d30344c241ecba58a9baf57d8cc7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8296d30344c241ecba58a9baf57d8cc7 = echarts.init(
#                     document.getElementById('8296d30344c241ecba58a9baf57d8cc7'), 'white', {renderer: 'canvas'});
#                 var option_8296d30344c241ecba58a9baf57d8cc7 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "pie",
#                 "name": "\u5546\u5bb6A",
#                 "clockwise": true,
#                 "data": [
#                     {
#                         "name": "\u886c\u886b",
#                         "value": 38
#                     },
#                     {
#                         "name": "\u6bdb\u8863",
# ...

# %%
import pandas as pd
a = [1,2,3,4,5]
b = [1,2,3,4,5]
c = [1,2,3,4,5]
d = list(zip(a,b,c))
y7 = pd.DataFrame(d)
y7
d
# Out:
# [(1, 1, 1), (2, 2, 2), (3, 3, 3), (4, 4, 4), (5, 5, 5)]

# %% [markdown]
# #### 绘制时间序列柱状图

# %%
# 绘制时间序列柱状图
from pyecharts import options as opts
from pyecharts.charts import Bar, Timeline
from pyecharts.faker import Faker

tl = Timeline()
for i in range(2015, 2020):
    bar = (
        Bar()
        .add_xaxis(Faker.choose())
        .add_yaxis("商家A", Faker.values(), label_opts=opts.LabelOpts(position="right"))
        .add_yaxis("商家B", Faker.values(), label_opts=opts.LabelOpts(position="right"))
        .reversal_axis()
        .set_global_opts(
            title_opts=opts.TitleOpts("Timeline-Bar-Reversal (时间: {} 年)".format(i))
        )
    )
    tl.add(bar, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5f61eb73d2d74a9faf469e8c049bb73b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5f61eb73d2d74a9faf469e8c049bb73b = echarts.init(
#                     document.getElementById('5f61eb73d2d74a9faf469e8c049bb73b'), 'white', {renderer: 'canvas'});
#                 var option_5f61eb73d2d74a9faf469e8c049bb73b = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": "\u5546\u5bb6A",
#                 "legendHoverLink": true,
#                 "data": [
#                     75,
#                     82,
#                     45,
#                     144,
#                     80,
#                     52,
#                     60
#                 ],
# ...

# %% [markdown]
# ### 绘制页面

# %%
# 绘制页面
page = (
    Page(layout=Page.DraggablePageLayout)
    .add(
        bar,
        pie,
        line
)
)
page.render("DraggablePageLayout.html")
# 调用绘制函数后生成一个 DraggablePageLayout.html 文件。
# 打开后可以其中的图片进行拖拽，来实现自定义布局。
# 对图片布局完毕后，要记得点击左上角“save config”对布局文件进行保存。
# 点击后，本地会生成一个chart_config.json的文件，这其中包含了每个图表ID对应的布局位置。
# Out:
# '/Users/zhangjinwei/Desktop/机器学习/001_学习数据/DraggablePageLayout.html'

# %%
# 最后，调用保存好的布局文件，重新生成html。
page.save_resize_html('DraggablePageLayout.html', cfg_file='chart_config.json', dest='new_DraggablePageLayout.html')
# DraggablePageLayout.html 为生成的所有图表的文件，chart_config.json 为下载的布局文件，new_DraggablePageLayout.html 为布局好的的仪表盘文件。
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/zhangjinwei/Desktop/机器学习/pyecharts绘图.ipynb Cell 41 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/zhangjinwei/Desktop/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/pyecharts%E7%BB%98%E5%9B%BE.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> # 最后，调用保存好的布局文件，重新生成html。
# ----> <a href='vscode-notebook-cell:/Users/zhangjinwei/Desktop/%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0/pyecharts%E7%BB%98%E5%9B%BE.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> page.save_resize_html('DraggablePageLayout.html', cfg_file='chart_config.json', dest='new_DraggablePageLayout.html')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pyecharts/charts/composite_charts/page.py:174, in Page.save_resize_html(source, cfg_file, cfg_dict, dest)
#     171     raise ValueError("Chart layout config is empty")
#     173 if cfg_file:
# ...
